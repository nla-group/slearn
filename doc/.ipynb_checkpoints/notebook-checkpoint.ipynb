# %%
# !pip uninstall slearn -y
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from slearn.slearn import *
# Out:
# WARNING: Skipping slearn as it is not installed.

# %% [markdown]
# ### sine data

# %%
ts = np.array([np.sin(0.05*i) for i in range(2000)])  # original time series
train = ts[:round(0.5*len(ts))]
test = ts[round(0.5*len(ts)):]

# %%
sl = slearn(series=train, method='fABBA', 
            ws=10, step=50,
            tol=0.01, alpha=0.3, # symbolic representaion parameters, you will need to change it if you use SAX
            form='numeric', classifier_name="GaussianNB",
            random_seed=1, verbose=1)
sklearn_params = {'var_smoothing':0.001} # sklearn parameters, setting any you want
abba_nb_pred = sl.predict(**sklearn_params)
# Out:
# 2021-11-30 18:12:49,717;INFO;Digitization: Reduced pieces of length 36 to 7  symbols
# -------- Config --------
# The length of time series:  1000
# The number of symbols:  36
# The dimension of features is:  10
# The number of symbols to be predicted:  50
# The parameters of classifiers:  {'var_smoothing': 0.001}
# /home/research/xinyechen/Paper work/slearn/slearn/slearn.py:191: UserWarning: fail to set_random_state.
#   warnings.warn("fail to set_random_state.")

# %%
sl = slearn(series=train, method='fABBA',
            ws=3, step=50,
            tol=0.01, alpha=0.1, 
            form='numeric', classifier_name="MLPClassifier",
            random_seed=1, verbose=1)
sklearn_params = {'hidden_layer_sizes':(20,80), 'learning_rate_init':0.1}
abba_nn_pred = sl.predict(**sklearn_params)
# Out:
# 2021-11-30 18:12:49,745;INFO;Digitization: Reduced pieces of length 36 to 10  symbols
# -------- Config --------
# The length of time series:  1000
# The number of symbols:  36
# The dimension of features is:  3
# The number of symbols to be predicted:  50
# The parameters of classifiers:  {'hidden_layer_sizes': (20, 80), 'learning_rate_init': 0.1}

# %% [markdown]
# or you can try another way for parameters assignment.

# %%
sl = slearn(series=train, method='fABBA',
            ws=3, step=50,
            tol=0.01, alpha=0.2, 
            form='numeric', classifier_name="MLPClassifier",
            random_seed=1, verbose=1)
abba_nn_pred = sl.predict(hidden_layer_sizes=(20,80), learning_rate_init=0.1)
# Out:
# 2021-11-30 18:12:49,850;INFO;Digitization: Reduced pieces of length 36 to 9  symbols
# -------- Config --------
# The length of time series:  1000
# The number of symbols:  36
# The dimension of features is:  3
# The number of symbols to be predicted:  50
# The parameters of classifiers:  {'hidden_layer_sizes': (20, 80), 'learning_rate_init': 0.1}

# %%
min_len = len(test)
sns.set_theme(style="whitegrid")
plt.figure(figsize=(25, 9))
sns.set(font_scale=2, style="whitegrid")
sns.lineplot(x=np.arange(0, len(train)), y=train, color='c', linewidth=6, label='Time series')
sns.lineplot(x=np.arange(len(train), len(train)+min_len), y=abba_nb_pred[:min_len], color='tomato', linewidth=6, label='Prediction (ABBA - GaussianNB)')
sns.lineplot(x=np.arange(len(train), len(train)+min_len), y=abba_nn_pred[:min_len], color='darkgreen', linewidth=6, label='Prediction (ABBA - MLPClassifier)')
plt.tight_layout()
plt.tick_params(axis='both', labelsize=25)
plt.show()

# %% [markdown]
# ### real world data

# %%
time_series = pd.read_csv("Amazon.csv")
ts = time_series.Close.values
# ts = [np.sin(0.05*i) for i in range(1000)]

# %%
plt.figure(figsize=(20, 5))
sns.set_theme(style="whitegrid")
sns.lineplot(data=ts)
plt.show()

# %%
step = 100 # predict 30 symbolss

# %%
sl = slearn(series=ts, method='ABBA', 
            ws=10, step=step,
            tol=0.01, alpha=0.3, 
            form='numeric', classifier_name="GaussianNB",
            random_seed=1, verbose=1)
sklearn_params = {'var_smoothing':0.001}
abba_nb_pred = sl.predict(**sklearn_params)
# Out:
# 2021-11-30 16:05:47,095;INFO;Digitization: Reduced pieces of length 77 to 16  symbols
# -------- Config --------
# The length of time series:  6155
# The number of symbols:  77
# The dimension of features is:  10
# The number of symbols to be predicted:  100
# The parameters of classifiers:  {'var_smoothing': 0.001}
# /home/research/xinyechen/.local/lib/python3.9/site-packages/slearn/slearn.py:191: UserWarning: fail to set_random_state.
#   warnings.warn("fail to set_random_state.")

# %%
sl = slearn(series=ts, method='ABBA',
            ws=10, step=step,
            tol=0.01, alpha=0.3, 
            form='numeric', classifier_name="MLPClassifier",
            random_seed=1, verbose=1)
sklearn_params = {'hidden_layer_sizes':(20,80), 'learning_rate_init':0.01, 'random_state':0}
abba_nn_pred = sl.predict(**sklearn_params)
# Out:
# 2021-11-30 16:05:47,526;INFO;Digitization: Reduced pieces of length 77 to 16  symbols
# -------- Config --------
# The length of time series:  6155
# The number of symbols:  77
# The dimension of features is:  10
# The number of symbols to be predicted:  100
# The parameters of classifiers:  {'hidden_layer_sizes': (20, 80), 'learning_rate_init': 0.01, 'random_state': 0}

# %%
plt.figure(figsize=(20, 5))
sns.set_theme(style="whitegrid")
sns.lineplot(data=abba_nb_pred)
sns.lineplot(data=abba_nn_pred)
plt.show()

# %%
plt.figure(figsize=(25, 9))
min_len = np.min([len(abba_nb_pred), len(abba_nn_pred)])
sns.set(font_scale=2, style="whitegrid")
sns.lineplot(x=np.arange(0, len(ts)), y= ts, color='c', linewidth=6, label='Time series')
sns.lineplot(x=np.arange(len(ts), len(ts)+min_len), y=abba_nb_pred[:min_len], color='tomato', linewidth=6, label='Prediction (ABBA - GaussianNB)')
sns.lineplot(x=np.arange(len(ts), len(ts)+min_len), y=abba_nn_pred[:min_len], color='darkgreen', linewidth=6, label='Prediction (ABBA - MLPClassifier)')
plt.tight_layout()
plt.tick_params(axis='both', labelsize=25)
plt.savefig("demo.PNG")
plt.show()
